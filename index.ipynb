# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
import sqlite3
import pandas as pd

conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %%
cur.execute(''' SELECT employees.firstName, employees.lastName, offices.city, offices.state FROM employees, offices ORDER BY firstName, lastName''').fetchall()
# Out:
# [('Andy', 'Fixter', 'San Francisco', 'CA'),
#  ('Andy', 'Fixter', 'Boston', 'MA'),
#  ('Andy', 'Fixter', 'NYC', 'NY'),
#  ('Andy', 'Fixter', 'Paris', ''),
#  ('Andy', 'Fixter', 'Tokyo', 'Chiyoda-Ku'),
#  ('Andy', 'Fixter', 'Sydney', ''),
#  ('Andy', 'Fixter', 'London', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Anthony', 'Bow', 'Boston', 'MA'),
#  ('Anthony', 'Bow', 'NYC', 'NY'),
#  ('Anthony', 'Bow', 'Paris', ''),
#  ('Anthony', 'Bow', 'Tokyo', 'Chiyoda-Ku'),
#  ('Anthony', 'Bow', 'Sydney', ''),
#  ('Anthony', 'Bow', 'London', ''),
#  ('Barry', 'Jones', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'Boston', 'MA'),
#  ('Barry', 'Jones', 'NYC', 'NY'),
#  ('Barry', 'Jones', 'Paris', ''),
#  ('Barry', 'Jones', 'Tokyo', 'Chiyoda-Ku'),
#  ('Barry', 'Jones', 'Sydney', ''),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Diane', 'Murphy', 'Boston', 'MA'),
#  ('Diane', 'Murphy', 'NYC', 'NY'),
#  ('Diane', 'Murphy', 'Paris', ''),
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute('''SELECT customers.customerName, orders.orderNumber, 
            orders.orderDate, orders.status FROM customers, orders;''').fetchall()
# Out:
# [('Atelier graphique', '10100', '2003-01-06', 'Shipped'),
#  ('Atelier graphique', '10101', '2003-01-09', 'Shipped'),
#  ('Atelier graphique', '10102', '2003-01-10', 'Shipped'),
#  ('Atelier graphique', '10103', '2003-01-29', 'Shipped'),
#  ('Atelier graphique', '10104', '2003-01-31', 'Shipped'),
#  ('Atelier graphique', '10105', '2003-02-11', 'Shipped'),
#  ('Atelier graphique', '10106', '2003-02-17', 'Shipped'),
#  ('Atelier graphique', '10107', '2003-02-24', 'Shipped'),
#  ('Atelier graphique', '10108', '2003-03-03', 'Shipped'),
#  ('Atelier graphique', '10109', '2003-03-10', 'Shipped'),
#  ('Atelier graphique', '10110', '2003-03-18', 'Shipped'),
#  ('Atelier graphique', '10111', '2003-03-25', 'Shipped'),
#  ('Atelier graphique', '10112', '2003-03-24', 'Shipped'),
#  ('Atelier graphique', '10113', '2003-03-26', 'Shipped'),
#  ('Atelier graphique', '10114', '2003-04-01', 'Shipped'),
#  ('Atelier graphique', '10115', '2003-04-04', 'Shipped'),
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute('''SELECT * FROM orderdetails''').fetchall()
# Out:
# [('10100', 'S18_1749', '30', '136.00', '3'),
#  ('10100', 'S18_2248', '50', '55.09', '2'),
#  ('10100', 'S18_4409', '22', '75.46', '4'),
#  ('10100', 'S24_3969', '49', '35.29', '1'),
#  ('10101', 'S18_2325', '25', '108.06', '4'),
#  ('10101', 'S18_2795', '26', '167.06', '1'),
#  ('10101', 'S24_1937', '45', '32.53', '3'),
#  ('10101', 'S24_2022', '46', '44.35', '2'),
#  ('10102', 'S18_1342', '39', '95.55', '2'),
#  ('10102', 'S18_1367', '41', '43.13', '1'),
#  ('10103', 'S10_1949', '26', '214.30', '11'),
#  ('10103', 'S10_4962', '42', '119.67', '4'),
#  ('10103', 'S12_1666', '27', '121.64', '8'),
#  ('10103', 'S18_1097', '35', '94.50', '10'),
#  ('10103', 'S18_2432', '22', '58.34', '2'),
#  ('10103', 'S18_2949', '27', '92.19', '12'),
#  ('10103', 'S18_2957', '35', '61.84', '14'),
#  ('10103', 'S18_3136', '25', '86.92', '13'),
#  ('10103', 'S18_3320', '46', '86.31', '16'),
#  ('10103', 'S18_4600', '36', '98.07', '5'),
#  ('10103', 'S18_4668', '41', '40.75', '9'),
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
# Your code here
cur.execute('''SELECT * FROM orderdetails 
            join products
            using (productCode)''').fetchall()
# Out:
# [('10100',
#   'S18_1749',
#   '30',
#   '136.00',
#   '3',
#   '1917 Grand Touring Sedan',
#   'Vintage Cars',
#   '1:18',
#   'Welly Diecast Productions',
#   'This 1:18 scale replica of the 1917 Grand Touring car has all the features you would expect from museum quality reproductions: all four doors and bi-fold hood opening, detailed engine and instrument panel, chrome-look trim, and tufted upholstery, all topped off with a factory baked-enamel finish.',
#   '2724',
#   '86.70',
#   '170.00'),
#  ('10100',
#   'S18_2248',
#   '50',
#   '55.09',
#   '2',
#   '1911 Ford Town Car',
#   'Vintage Cars',
#   '1:18',
#   'Motor City Art Classics',
#   'Features opening hood, opening doors, opening trunk, wide white wall tires, front door arm rests, working steering system.',
#   '540',
#   '33.30',
#   '60.54'),
#  ('10100',
#   'S18_4409',
#   '22',
#   '75.46',
#   '4',
#   '1932 Alfa Romeo 8C2300 Spider Sport',
#   'Vintage Cars',
#   '1:18',
#   'Exoto Designs',
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
